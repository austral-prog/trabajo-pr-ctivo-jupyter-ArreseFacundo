# %% [markdown]
# # Assignment
#
# The assignment will require you to complete cells, create new ones, and move around some cells. You need to familiarize yourself with the Jupyter notebook interface. You can find a tutorial [here](https://www.dataquest.io/blog/jupyter-notebook-tutorial/).
#
#
# **MAKE SURE TO MAKE A COPY OF THIS ASSIGNMENT IN YOUR OWN REPOSITORY.** (delete this line in your new copy :) )

# %% [markdown]
# ---

# %% [markdown]
# # [EXERCISE 1]
#
# ## Facundo Arrese
# ## farrese@mail.austral.edu.ar
# ![image.png](attachment:38e96f40-04a4-4694-9823-10e2da2539d4.png)
# la foto muestra un cartel del lugar que mas me gusta en el mundo. es en brasil. me gusta este lugar porque voy con mi familia y hago surf con todos mis primos

# %%
a=3
b=7

# %% [markdown]
# ## suma

# %%
a+b
# Out:
# 10

# %% [markdown]
# ## resta

# %%
a-b
# Out:
# -4

# %% [markdown]
# ## multiplicacion

# %%
a*b
# Out:
# 21

# %% [markdown]
# ## division

# %%
a/b
# Out:
# 0.42857142857142855
